# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIKUNDAN1/Capable-Project/blob/main/Travel_Concierge_RAG_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the core Track A stack
# !pip install -q -U langchain langchain-google-genai google-generativeai pypdf faiss-cpu python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.8/173.8 kB 11.9 MB/s eta 0:00:00

# %%
from google.colab import userdata
import os

# This replaces the need for a .env file locally
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %%
import os

# Creating the structure required by the Project Overview
folders = ['data/raw', 'data/processed']
for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Data folders created! Upload your travel PDFs to data/raw/ now.")
# Out:
# Data folders created! Upload your travel PDFs to data/raw/ now.
